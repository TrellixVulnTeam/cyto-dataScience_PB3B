# %%
import sys
sys.path.append('/home/dan/Dropbox/Create/ThinAir/CytoDynamic/master')
import cv2
import matplotlib.pyplot as plt
import image as img
import copy
import numpy as np
import pandas as pd
from waveform import *

# %%
# %matplotlib widget
im = img.Image('/home/dan/Dropbox/Create/ThinAir/CytoDynamic/master/RK1.jpg',0)
im.show_gray_im()
test = im.image
test.dtype
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# dtype('uint8')

# %%
im.show_hist()
stretch = im.simple_stretch(100, 150)
stretch.show_hist()
# %python ./scratch.py
# Out:
# UsageError: Line magic function `%python` not found (But cell magic `%%python` exists, did you mean that instead?).

# %%
threshold_im = copy.deepcopy(im)
ret, thresh1 = cv2.threshold(threshold_im.image, 0, 0, cv2.THRESH_BINARY)
threshold_im.image = thresh1
threshold_im.show_gray_im()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-34d0dcc6a4b1> in <module>
# ----> 1 threshold_im = copy.deepcopy(im)
#       2 ret, thresh1 = cv2.threshold(threshold_im.image, 0, 0, cv2.THRESH_BINARY)
#       3 threshold_im.image = thresh1
#       4 threshold_im.show_gray_im()
#
# NameError: name 'copy' is not defined

# %%
hist_im = copy.deepcopy(im)
plt.hist(hist_im.image.ravel(),256,[0,256]); plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-541f27bd64ef> in <module>
# ----> 1 hist_im = copy.deepcopy(im)
#       2 plt.hist(hist_im.image.ravel(),256,[0,256]); plt.show()
#
# NameError: name 'copy' is not defined

# %%
q = cv2.imread('/home/dan/Dropbox/Create/ThinAir/CytoDynamic/master/messi.jpg',0)
f = np.fft.fft2(q)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))
plt.subplot(121),plt.imshow(q, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
test = cv2.imread('messi.jpg',0)
