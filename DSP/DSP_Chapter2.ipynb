# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math

# %%
n = np.arange(64)
N = n.size
x = ((2*np.pi*n)/N)
k = 2
y = np.sin(2 * np.pi * k * (n/N))

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x,y)

locs, labels = xticks()
x_ticks = []
for i in range(0,9):
    x_ticks.append((i*np.pi)/4)
print(x_ticks)
x_labels = [0, r'$\frac{\pi}{4}$', r'$\frac{\pi}{2}$', r'$\frac{3\pi}{4}$', r'$\pi$', r'$\frac{5\pi}{4}$', r'$\frac{3\pi}{2}$', r'$\frac{7\pi}{4}$', r'$2\pi$']
xticks(x_ticks, x_labels)
# Out:
# [0.0, 0.7853981633974483, 1.5707963267948966, 2.356194490192345, 3.141592653589793, 3.9269908169872414, 4.71238898038469, 5.497787143782138, 6.283185307179586]
# ([<matplotlib.axis.XTick at 0x7f7e4c0be640>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 0, '$\\frac{\\pi}{4}$'),
#   Text(0, 0, '$\\frac{\\pi}{2}$'),
#   Text(0, 0, '$\\frac{3\\pi}{4}$'),
#   Text(0, 0, '$\\pi$'),
#   Text(0, 0, '$\\frac{5\\pi}{4}$'),
#   Text(0, 0, '$\\frac{3\\pi}{2}$'),
#   Text(0, 0, '$\\frac{7\\pi}{4}$'),
#   Text(0, 0, '$2\\pi$')])

# %%
a = np.arange(15)
a = a.reshape(3,5)
a.shape
a.ndim
a.dtype.name
# Out:
# 'int64'

# %%
from pylab import *
from basic_units import radians

x = arange(-10.0,10.0,0.1)
y = map(lambda y: y*radians,arctan(x))
x = map(lambda x: x*radians,x)

plot(x,y,'b.',xunits=radians,yunits=radians)
show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-25-f7aad199fd66> in <module>
#       6 x = map(lambda x: x*radians,x)
#       7
# ----> 8 plot(x,y,'b.',xunits=radians,yunits=radians)
#       9 show()
#
# ~/Dropbox/Create/ThinAir/CytoDynamic/cv-env/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# ~/Dropbox/Create/ThinAir/CytoDynamic/cv-env/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...
